# %%
import geopandas as gpd

# %%
table_file = 'a0000000a.gdbtable'
df = gpd.read_file(table_file, crs='epsg:4326')

# %%
df.head()
# Out:
#      ref_no                            name pointx_class    groupname  \
# 0  21864924  Bus Stop (Grove Farm Cottages)     10590732    Transport
# 1  20279522                            Moat     03170245  Attractions
# 2  20279821                            Moat     03170245  Attractions
# 3  20279822                            Moat     03170245  Attractions
# 4  21859718       Bus Stop (Albion Terrace)     10590732    Transport
#
#               categoryname                           classname  \
# 0            Bus Transport                           Bus Stops
# 1  Historical and Cultural  Historic and Ceremonial Structures
# 2  Historical and Cultural  Historic and Ceremonial Structures
# 3  Historical and Cultural  Historic and Ceremonial Structures
# 4            Bus Transport                           Bus Stops
#
#    feature_easting  feature_northing  pos_accuracy  uprn  ... postcode  \
# 0         559498.0          184352.0             1  None  ...     RM15
# 1         531404.0          196330.0             2  None  ...      EN2
# 2         524417.0          197646.0             2  None  ...      EN5
# 3         525419.0          189921.0             2  None  ...       N3
# 4         537731.0          196190.0             1  None  ...       E4
#
#            admin_boundary telephone_number   url  brand qualifier_type  \
# 0                Thurrock             None  None   None     SMS Number
# 1     Enfield London Boro             None  None   None           None
# 2      Barnet London Boro             None  None   None           None
# 3      Barnet London Boro             None  None   None           None
# 4  Epping Forest District             None  None   None     SMS Number
#
#   qualifier_data                provenance supply_date  \
# 0        thuagwd  Department for Transport  2022-06-01
# 1           None           Ordnance Survey  2022-06-01
# 2           None           Ordnance Survey  2022-06-01
# 3           None           Ordnance Survey  2022-06-01
# 4       esxdgtdm  Department for Transport  2022-06-01
#
#                         geometry
# 0  POINT (559498.000 184352.000)
# 1  POINT (531404.000 196330.000)
# 2  POINT (524417.000 197646.000)
# 3  POINT (525419.000 189921.000)
# 4  POINT (537731.000 196190.000)
#
# [5 rows x 29 columns]

# %%
groupname = df['groupname'].unique().tolist()
groupname
# Out:
# ['Transport',
#  'Attractions',
#  'Education and Health',
#  'Commercial Services',
#  'Public Infrastructure',
#  'Accommodation, Eating and Drinking',
#  'Manufacturing and Production',
#  'Retail',
#  'Sport and Entertainment']

# %%
# Filter groupname by Sport and Entertainment

df_ls = df.loc[df['groupname'] == 'Sport and Entertainment']

# %%
df_ls.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 11082 entries, 39123 to 338702
# Data columns (total 29 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ref_no             11082 non-null  int64
#  1   name               11082 non-null  object
#  2   pointx_class       11082 non-null  object
#  3   groupname          11082 non-null  object
#  4   categoryname       11082 non-null  object
#  5   classname          11082 non-null  object
#  6   feature_easting    11082 non-null  float64
#  7   feature_northing   11082 non-null  float64
#  8   pos_accuracy       11082 non-null  int64
#  9   uprn               6852 non-null   object
#  10  topo_toid          11082 non-null  object
#  11  topo_toid_version  11082 non-null  int64
#  12  usrn               11082 non-null  object
#  13  usrn_mi            11082 non-null  int64
#  14  distance           11082 non-null  float64
#  15  address_detail     6763 non-null   object
#  16  street_name        6968 non-null   object
#  17  locality           7105 non-null   object
#  18  geographic_county  11082 non-null  object
#  19  postcode           11082 non-null  object
#  20  admin_boundary     11082 non-null  object
#  21  telephone_number   5959 non-null   object
#  22  url                4124 non-null   object
#  23  brand              2728 non-null   object
#  24  qualifier_type     0 non-null      object
#  25  qualifier_data     0 non-null      object
#  26  provenance         11082 non-null  object
#  27  supply_date        11082 non-null  datetime64[ns]
#  28  geometry           11082 non-null  geometry
# dtypes: datetime64[ns](1), float64(3), geometry(1), int64(4), object(20)
# memory usage: 2.5+ MB

# %%
# pick the columns that we need
df_pick = df_ls.loc[:,['name','groupname','categoryname','classname','feature_easting','feature_northing','admin_boundary','geometry']]
df_pick.columns
# Out:
# Index(['name', 'groupname', 'categoryname', 'classname', 'feature_easting',
#        'feature_northing', 'admin_boundary', 'geometry'],
#       dtype='object')

# %%
df_pick
# Out:
#                                                      name  \
# 39123                                   Hillcroft C C Ltd
# 40188   The Cherry Red Records Stadium (A F C Wimbledo...
# 40676                                 Jazz After Dark Ltd
# 41154                        Top Meadow Golf Club & Hotel
# 43505                                       West Five Bar
# ...                                                   ...
# 338639                           Putney Box Fit Jiu Jitsu
# 338647                                               Umaa
# 338668                                                F45
# 338698                            Brentford Football Club
# 338702                                  Gametime Playtime
#
#                       groupname              categoryname  \
# 39123   Sport and Entertainment            Sports Complex
# 40188   Sport and Entertainment            Sports Complex
# 40676   Sport and Entertainment  Venues, Stage and Screen
# 41154   Sport and Entertainment            Sports Complex
# 43505   Sport and Entertainment  Venues, Stage and Screen
# ...                         ...                       ...
# 338639  Sport and Entertainment            Sports Complex
# 338647  Sport and Entertainment            Sports Complex
# 338668  Sport and Entertainment            Sports Complex
# 338698  Sport and Entertainment            Sports Complex
# 338702  Sport and Entertainment                  Gambling
#
#                                             classname  feature_easting  \
# 39123                             Shooting Facilities         516655.0
# 40188              Sports Grounds, Stadia and Pitches         519510.0
# 40676                                      Nightclubs         529784.0
# 41154   Golf Ranges, Courses, Clubs and Professionals         559923.9
# 43505                                      Nightclubs         517878.0
# ...                                               ...              ...
# 338639   Gymnasiums, Sports Halls and Leisure Centres         523774.0
# 338647   Gymnasiums, Sports Halls and Leisure Centres         532109.0
# 338668   Gymnasiums, Sports Halls and Leisure Centres         521018.0
# 338698             Sports Grounds, Stadia and Pitches         518933.0
# 338702                    Amusement Parks and Arcades         521873.2
#
#         feature_northing                    admin_boundary  \
# 39123           160039.0  Kingston upon Thames London Boro
# 40188           168730.0  Kingston upon Thames London Boro
# 40676           181163.0   City of Westminster London Boro
# 41154           184982.0              Havering London Boro
# 43505           179100.0                Ealing London Boro
# ...                  ...                               ...
# 338639          175780.0            Wandsworth London Boro
# 338647          162372.0               Croydon London Boro
# 338668          192760.0                Barnet London Boro
# 338698          178210.0              Hounslow London Boro
# 338702          192250.6                Barnet London Boro
#
#                              geometry
# 39123   POINT (516655.000 160039.000)
# 40188   POINT (519510.000 168730.000)
# 40676   POINT (529784.000 181163.000)
# 41154   POINT (559923.900 184982.000)
# 43505   POINT (517878.000 179100.000)
# ...                               ...
# 338639  POINT (523774.000 175780.000)
# 338647  POINT (532109.000 162372.000)
# 338668  POINT (521018.000 192760.000)
# 338698  POINT (518933.000 178210.000)
# 338702  POINT (521873.200 192250.600)
#
# [11082 rows x 8 columns]

# %%
categoryname = df_pick['categoryname'].unique().tolist()
categoryname
# Out:
# ['Sports Complex',
#  'Venues, Stage and Screen',
#  'Sport and Entertainment Support Services',
#  'Gambling',
#  'Outdoor Pursuits']

# %%
df_pick.to_crs('epsg:27700').plot(cmap='viridis', markersize=1, figsize=(12,8));
